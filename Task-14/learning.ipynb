# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd

# %%
import numpy as np

# %%
# specify additional values to be treated as NaN
na_vals = ['NA', 'Missing']
df = pd.read_csv(r"C:\Users\Nada\Downloads\survey_results_public.csv", index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv(r"C:\Users\Nada\Downloads\survey_results_schema.csv", index_col='Column')

# %%
# set max number of rows and columns to display
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: str

# %%
df['YearsCode'].unique()
# Out:
# <StringArray>
# [                 '4',                  nan,                  '3',
#                  '16',                 '13',                  '6',
#                   '8',                 '12',                  '2',
#                   '5',                 '17',                 '10',
#                  '14',                 '35',                  '7',
#    'Less than 1 year',                 '30',                  '9',
#                  '26',                 '40',                 '19',
#                  '15',                 '20',                 '28',
#                  '25',                  '1',                 '22',
#                  '11',                 '33',                 '50',
#                  '41',                 '18',                 '34',
#                  '24',                 '23',                 '42',
#                  '27',                 '21',                 '36',
#                  '32',                 '39',                 '38',
# ...

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
# Out:
# C:\Users\Nada\AppData\Local\Temp\ipykernel_8832\4290426552.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
# Respondent
# 1          4
# 2        NaN
# 3          3
# 4          3
# 5         16
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# ...

# %%
df['YearsCode'] = df['YearsCode'].replace('Less than 1 year', 0)

# %%
df['YearsCode']=df['YearsCode'].replace('More than 50 years', 51)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# np.float64(11.662114216834588)

# %%
df['YearsCode'].median()
# Out:
# np.float64(9.0)

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
# replace NA and Missing values with NaN for proper missing data handling
h = pd.DataFrame(people)

h.replace('NA', np.nan, inplace=True)
h.replace('Missing', np.nan, inplace=True)
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@email.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
h.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
# drop rows where both last and email are NaN
h.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 5    NaN      NaN      Anonymous@email.com  NaN

# %%
h.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
h.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
h.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object

# %%
h['age'] = h['age'].astype(float)

# %%
h['age'].mean()
# Out:
# np.float64(46.75)

# %% [markdown]
# ### Handling missing values

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
# 'isnull' returns a DataFrame of booleans (True if missing, False if not missing)
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
# 'nonnull' returns the opposite of 'isnull' (True if not missing, False if missing)
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %%
ufo.isnull().sum()
# Out:
# City                  26
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
# show first 5 rows where City is missing (NaN)
ufo[ufo.City.isnull()].head()
# Out:
#     City Colors Reported Shape Reported State             Time
# 21   NaN             NaN            NaN    LA   8/15/1943 0:00
# 22   NaN             NaN          LIGHT    LA   8/15/1943 0:00
# 204  NaN             NaN           DISK    CA  7/15/1952 12:30
# 241  NaN            BLUE           DISK    MT   7/4/1953 14:00
# 613  NaN             NaN           DISK    NV   7/1/1960 12:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(how='any').shape
# Out:
# (2486, 5)

# %%
# if 'all' values are missing in a row, then drop that row (none are dropped in this case)
ufo.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
ufo.dropna(subset=['City', 'Shape Reported'], how='any').shape
# Out:
# (15575, 5)

# %%
ufo.dropna(subset=['City', 'Shape Reported'], how='all').shape
# Out:
# (18237, 5)

# %%
# count occurrences of each value including optional handling of missing values
ufo['Shape Reported'].value_counts().head()
# Out:
# Shape Reported
# LIGHT       2803
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# CIRCLE      1365
# Name: count, dtype: int64

# %%
ufo['Shape Reported'].value_counts(dropna=False).head()
# Out:
# Shape Reported
# LIGHT       2803
# NaN         2644
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# Name: count, dtype: int64

# %%
# fill in missing values with a specified value
ufo.fillna({'Shape Reported': 'VARIOUS'}, inplace=True)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN        VARIOUS    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %% [markdown]
# ### Datetime-Timeseries

# %%
from datetime import datetime

# %%
d = pd.read_csv(r"C:\Users\Nada\Downloads\ETH_1h.csv")

d['Date'] = pd.to_datetime(d['Date'], format='%Y-%m-%d %I-%p')

# %%
d.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
d.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
d['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: str

# %%
d['DayOfWeek'] = d['Date'].dt.day_name()
d
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
d['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
d['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
d['Date'].max() - d['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
# filter rows between 2019-01-01 and 2020-01-01
filt = (d['Date'] >= pd.to_datetime('2019-01-01')) & (d['Date'] < pd.to_datetime('2020-01-01'))
d.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
# set Date column as index for time series analysis
d
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
d.index
# Out:
# DatetimeIndex(['2020-03-13 20:00:00', '2020-03-13 19:00:00',
#                '2020-03-13 18:00:00', '2020-03-13 17:00:00',
#                '2020-03-13 16:00:00', '2020-03-13 15:00:00',
#                '2020-03-13 14:00:00', '2020-03-13 13:00:00',
#                '2020-03-13 12:00:00', '2020-03-13 11:00:00',
#                ...
#                '2017-07-01 20:00:00', '2017-07-01 19:00:00',
#                '2017-07-01 18:00:00', '2017-07-01 17:00:00',
#                '2017-07-01 16:00:00', '2017-07-01 15:00:00',
#                '2017-07-01 14:00:00', '2017-07-01 13:00:00',
#                '2017-07-01 12:00:00', '2017-07-01 11:00:00'],
#               dtype='datetime64[us]', name='Date', length=23674, freq=None)

# %%
d['2020-01':'2020-02']['Close'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 d['2020-01':'2020-02']['Close'].mean()
#
# File c:\Users\Nada\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4361, in DataFrame.__getitem__(self, key)
#    4357                 return self._getitem_multilevel(key)
#    4358
#    4359         # Do we have a slicer (on rows)?
#    4360         if isinstance(key, slice):
# -> 4361             return self._getitem_slice(key)
#    4362
#    4363         # Do we have a (boolean) DataFrame?
#    4364         if isinstance(key, DataFrame):
#
# File c:\Users\Nada\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4298, in NDFrame._getitem_slice(self, key)
#    4294         __getitem__ for the case where the key is a slice object.
#    4295         """
# ...

# %%
d = d.sort_index()

# %%
d['2020-01':'2020-02']['Close'].mean()
# Out:
# np.float64(195.1655902777778)

# %%
d['2020-01-01']['High'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Nada\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
d.loc['2020-01-01', 'High'].max()
# Out:
# np.float64(132.68)

# %%
d
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# ...                     ...     ...     ...     ...     ...         ...
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
#
#                     DayOfWeek
# Date
# 2017-07-01 11:00:00  Saturday
# ...

# %%
highs = d['High'].resample('D').max()
highs['2020-01-01']
# Out:
# np.float64(132.68)

# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
d.resample('W').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 d.resample('W').mean()
#
# File c:\Users\Nada\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\resample.py:1532, in Resampler.mean(self, numeric_only)
#    1480 @final
#    1481 def mean(
#    1482     self,
#    1483     numeric_only: bool = False,
#    1484 ):
#    1485     """
#    1486     Compute mean of groups, excluding missing values.
#    1487
#    (...)   1530     Freq: MS, dtype: float64
#    1531     """
# -> 1532     return self._downsample("mean", numeric_only=numeric_only)
#
# File c:\Users\Nada\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\resample.py:2102, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    2098     return obj
#    2100 # we are downsampling
#    2101 # we want to call the actual grouper method here
# ...

# %%
d.resample('W').mean(numeric_only=True)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
# resample data weekly and apply different aggregation functions per column
d.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume': 'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]
