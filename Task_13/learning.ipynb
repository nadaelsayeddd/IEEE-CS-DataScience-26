# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\Nada\Downloads\survey_results_public.csv")

# %%
df1.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
df1.shape
# Out:
# (88883, 85)

# %%
# show more rows and columns in pandas output (increase display limit)
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv(r"C:\Users\Nada\Downloads\survey_results_schema.csv")

# %%
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df1.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# extract the Hobbyist column from the dataframe
df1['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: str

# %%
# select rows 0 to 2 and columns from Hobbyist to Employment
df1.loc[0:2, 'Hobbyist': 'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# ### Data Frame

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['email'] #✔✔
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: str

# %%
df.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: str

# %%
df[['last', 'email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.iloc[[0,1], 2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: str

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[[0,1], ['email', 'last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %% [markdown]
# ### Indexes

# %%
schema_df.loc[18, 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
# sort dataframe by index in-place (modify original dataframe)
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
# set email column as the index of the dataframe (use email as row identifier)
df.set_index('email', inplace=True)

# %%
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='str', name='email')

# %%
df.loc['CoreyMSchafer@gmail.com', 'last']
# Out:
# 'Schafer'

# %%
# select the first row of the dataframe using iloc
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: str

# %%
df.reset_index(inplace=True)
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %% [markdown]
# ### Filtering

# %%
df1.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
filt1 = df1['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
filt1
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df1.loc[filt1]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 88854       84539                                     NaN      Yes
# 88860       85738                                     NaN      Yes
# 88865       86566                                     NaN      Yes
# 88872       87739                                     NaN      Yes
# 88876       88212                                     NaN       No
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
filt = (df['last'] == 'Schafer') | (df['first'] == 'John')

# %%
# select email column for rows that do NOT match the filter
df.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: str

# %% [markdown]
# ### Updating Data

# %%
df1.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df1['SalaryUSD']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df1['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: str

# %%
# convert Hobbyist column values from Yes/No to True/False   # Boolean data is better in analysis
df1['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df1
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.columns = ['Email', 'First_name', 'Last_name']
df
# Out:
#                      Email First_name Last_name
# 0  CoreyMSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@email.com       Jane       Doe
# 2        JohnDoe@email.com       John       Doe

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#                      email first_name last_name
# 0  CoreyMSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@email.com       Jane       Doe
# 2        JohnDoe@email.com       John       Doe

# %%
df.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
df.loc[2] = ['JohnSmith@email.com', 'John', 'Smith']
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2      JohnSmith@email.com   John    Smith

# %%
df.loc[2, ['email', 'last']] = ['JohnDoe@email.com', 'Doe']
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df.loc[2,'last'] = 'Smith'
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John    Smith

# %%
df.at[2, 'last'] = 'Doe'
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
# update 'last' name to 'Smith' for rows matching the email using loc (avoid copy warning)
filt = (df['email'] == 'JohnDoe@email.com')
df.loc[filt, 'last'] = 'Smith'
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John    Smith

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com   John    Smith

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()
df['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: str

# %%
df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#                      email  first     last
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@EMAIL.COM   Jane      Doe
# 2        JOHNDOE@EMAIL.COM   John    Smith

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com   John    Smith

# %%
df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(pd.Series.min)
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: str

# %%
df.apply(lambda x: x.min())
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: str

# %%
df.map(len)
# Out:
#    email  first  last
# 0     23      5     7
# 1     17      4     3
# 2     17      4     5

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.map(str.lower)
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  corey  schafer
# 1        janedoe@email.com   jane      doe
# 2        johndoe@email.com   john    smith

# %%
df['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: str

# %%
df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com   John    Smith

# %%
df['first'] = df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})

# %%
df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Chris  Schafer
# 1        janedoe@email.com   Mary      Doe
# 2        johndoe@email.com   John    Smith

# %% [markdown]
# ### Add / Remove Rows/Columns

# %%
df2 = pd.read_csv(r"C:\Users\Nada\Downloads\survey_results_public.csv", index_col='Respondent')
schema_df2 = pd.read_csv(r"C:\Users\Nada\Downloads\survey_results_schema.csv", index_col='Column')

# %%
df2.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['full_name'] = df['first'] + ' ' + df['last']
df
# Out:
#                      email  first     last      full_name
# 0  coreymschafer@gmail.com  Chris  Schafer  Chris Schafer
# 1        janedoe@email.com   Mary      Doe       Mary Doe
# 2        johndoe@email.com   John    Smith     John Smith

# %%
df.drop(columns=['first', 'last'], inplace=True)
df
# Out:
#                      email      full_name
# 0  coreymschafer@gmail.com  Chris Schafer
# 1        janedoe@email.com       Mary Doe
# 2        johndoe@email.com     John Smith

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Mary Doe   Mary      Doe
# 2        johndoe@email.com     John Smith   John    Smith

# %%
#df.append({'first': 'Tony'}, ignore_index=True)
df = pd.concat([df, pd.DataFrame([{'first': 'Tony'}])], ignore_index=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Mary Doe   Mary      Doe
# 2        johndoe@email.com     John Smith   John    Smith
# 3                      NaN            NaN   Tony      NaN

# %%
people = {
    'first': ['Tony', 'Steve'], 
    'last': ['Stark', 'Rogers'], 
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
df4 = pd.DataFrame(people)

# %%
df4
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df = pd.concat([df, df4], ignore_index=True, sort=False)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Mary Doe   Mary      Doe
# 2        johndoe@email.com     John Smith   John    Smith
# 3                      NaN            NaN   Tony      NaN
# 4       IronMan@avenge.com            NaN   Tony    Stark
# 5           Cap@avenge.com            NaN  Steve   Rogers
# 6       IronMan@avenge.com            NaN   Tony    Stark
# 7           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop(index=3)
df.drop(index=4)
df.drop(index=5)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Mary Doe   Mary      Doe
# 2        johndoe@email.com     John Smith   John    Smith
# 3                      NaN            NaN   Tony      NaN
# 4       IronMan@avenge.com            NaN   Tony    Stark
# 6       IronMan@avenge.com            NaN   Tony    Stark
# 7           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop([3,4], inplace=True)

# %%
df.drop([5,6,7], inplace=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Mary Doe   Mary      Doe
# 2        johndoe@email.com     John Smith   John    Smith

# %%
df = pd.concat([df, df4], ignore_index=True, sort=False)
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Mary Doe   Mary      Doe
# 2        johndoe@email.com     John Smith   John    Smith
# 3       IronMan@avenge.com            NaN   Tony    Stark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop(index=4, inplace=True)
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@email.com       Mary Doe   Mary      Doe
# 2        johndoe@email.com     John Smith   John    Smith
# 3       IronMan@avenge.com            NaN   Tony    Stark

# %%
filt = df['last'] == 'Doe'
df.drop(index=df[filt].index)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2        johndoe@email.com     John Smith   John    Smith
# 3       IronMan@avenge.com            NaN   Tony    Stark

# %% [markdown]
# ### Sorting Data

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Adam'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Doe'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', 'A@email.com']
}

# %%
df5 = pd.DataFrame(people)

# %%
df5
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df5.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df5.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df5.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df5
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df5.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe              A@email.com

# %%
df5['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: str
